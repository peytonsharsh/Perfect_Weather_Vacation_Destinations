# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import datetime as dt

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
cities
# Out:
# ['georgetown',
#  'tuktoyaktuk',
#  'upernavik',
#  'paamiut',
#  'port elizabeth',
#  'taolanaro',
#  'butaritari',
#  'tsihombe',
#  'khatanga',
#  'vaini',
#  'cassilandia',
#  'boa vista',
#  'illoqqortoormiut',
#  'saskylakh',
#  'beira',
#  'simdega',
#  'rikitea',
#  'takoradi',
#  'mahebourg',
#  'cape town',
#  'nikolskoye',
#  'albany',
#  'ponta do sol',
#  'noto',
#  'thompson',
#  'mosetse',
#  'attawapiskat',
#  'castro',
#  'caravelas',
#  'surgana',
#  'carnarvon',
#  'tateyama',
#  'kwekwe',
#  'provideniya',
#  'airai',
#  'verkhnevilyuysk',
#  'mar del plata',
#  'hermanus',
#  'namibe',
#  'baracoa',
#  'grand river south east',
#  'shimanovsk',
#  'atar',
#  'bindura',
#  'santa fe',
#  'touros',
#  'vilhena',
#  'damavand',
#  'belushya guba',
#  'geraldton',
#  'esperance',
#  'asfi',
#  'chuy',
#  'ushuaia',
#  'ola',
#  'tiarei',
#  'miramar',
#  'salo',
#  'tiksi',
#  'gubkinskiy',
#  'punta arenas',
#  'greenville',
#  'bambanglipuro',
#  'cabo san lucas',
#  'coihaique',
#  'ribeira grande',
#  'sinnamary',
#  'arraial do cabo',
#  'atuona',
#  'longlac',
#  'saint george',
#  'padang',
#  'amurzet',
#  'oktyabrskoye',
#  'bluff',
#  'puerto baquerizo moreno',
#  'kalmunai',
#  'puerto ayora',
#  'pemba',
#  'cap malheureux',
#  'kapaa',
#  'port alfred',
#  'mataura',
#  'hilo',
#  'port hardy',
#  'mount gambier',
#  'emerald',
#  'luganville',
#  'walvis bay',
#  'muroto',
#  'lithgow',
#  'myaundzha',
#  'tuim',
#  'kondinskoye',
#  'biak',
#  'zelenogorskiy',
#  'cidreira',
#  'baruun-urt',
#  'olafsvik',
#  'tasiilaq',
#  'mentok',
#  'faya',
#  'grindavik',
#  'dikson',
#  'spornoye',
#  'puerto palomas',
#  'uwayl',
#  'saldanha',
#  'jacqueville',
#  'puerto carreno',
#  'asau',
#  'johi',
#  'le vauclin',
#  'bagamoyo',
#  'petropavlovsk-kamchatskiy',
#  'koumac',
#  'codrington',
#  'campoverde',
#  'eyl',
#  'lavrentiya',
#  'tuatapere',
#  'bandarbeyla',
#  'casablanca',
#  'hovd',
#  'kununurra',
#  'gyomaendrod',
#  'bintulu',
#  'aguimes',
#  'poum',
#  'saleaula',
#  'gimli',
#  'bredasdorp',
#  'bathsheba',
#  'saint-georges',
#  'liwale',
#  'avarua',
#  'wulanhaote',
#  'yulara',
#  'vanimo',
#  'severo-kurilsk',
#  'victoria',
#  'sao joao da barra',
#  'sungai siput utara',
#  'chapais',
#  'kodiak',
#  'torres',
#  'rolim de moura',
#  'yellowknife',
#  'sakassou',
#  'nizhneyansk',
#  'rio verde de mato grosso',
#  'san patricio',
#  'khurai',
#  'ancud',
#  'irbeyskoye',
#  'isangel',
#  'pevek',
#  'kavieng',
#  'fairbanks',
#  'urumqi',
#  'vostok',
#  'pasni',
#  'turbat',
#  'lebu',
#  'vao',
#  'loviisa',
#  'east london',
#  'hobart',
#  'tessalit',
#  'kazalinsk',
#  'urdzhar',
#  'longfeng',
#  'qaanaaq',
#  'ambovombe',
#  'barrow',
#  'mehamn',
#  'itambacuri',
#  'tabou',
#  'palmer',
#  'hofn',
#  'cloquet',
#  'pizhanka',
#  'louisbourg',
#  'bengkulu',
#  'guerrero negro',
#  'egvekinot',
#  'laguna',
#  'alofi',
#  'shunyi',
#  'bima',
#  'narsaq',
#  'santa ana',
#  'klaksvik',
#  'los llanos de aridane',
#  'ponyri',
#  'ayotzingo',
#  'mitchell',
#  'jamestown',
#  'methoni',
#  'ambilobe',
#  'bonavista',
#  'saint-philippe',
#  'meulaboh',
#  'hutchinson',
#  'sentyabrskiy',
#  'qasigiannguit',
#  'gat',
#  'bolungarvik',
#  'antofagasta',
#  'saint-francois',
#  'bien hoa',
#  'spas-klepiki',
#  'port augusta',
#  'diego de almagro',
#  'leshukonskoye',
#  'ponta delgada',
#  'hithadhoo',
#  'teacapan',
#  'marabba',
#  'hobyo',
#  'nueve de julio',
#  'mayya',
#  'constitucion',
#  'excelsior springs',
#  'virginia beach',
#  'haapiti',
#  'busselton',
#  'micheweni',
#  'amderma',
#  'jacmel',
#  'karaul',
#  'faanui',
#  'balimo',
#  'tomohon',
#  'villafranca de los barros',
#  'marathon',
#  'chokurdakh',
#  'nagapattinam',
#  'seoul',
#  'klyuchi',
#  'wukari',
#  'bafra',
#  'bo phloi',
#  'skagastrond',
#  'uglovka',
#  'new norfolk',
#  'shingu',
#  'port moresby',
#  'bilibino',
#  'luderitz',
#  'kahului',
#  'kariba',
#  'ternate',
#  'leningradskiy',
#  'goma',
#  'nhulunbuy',
#  'noumea',
#  'filadelfia',
#  'arlit',
#  'magdagachi',
#  'lompoc',
#  'conakry',
#  'vaitape',
#  'margate',
#  'aubenas',
#  'lahat',
#  'katsuura',
#  'itoman',
#  'lufilufi',
#  'saint-augustin',
#  'abu samrah',
#  'udachnyy',
#  'shitanjing',
#  'betafo',
#  'maragogi',
#  'elmira',
#  'quatre cocos',
#  'sao jose da coroa grande',
#  'tiznit',
#  'gonzales',
#  'batu',
#  'hamilton',
#  'nanortalik',
#  'souillac',
#  'goderich',
#  'myanaung',
#  'zlatibor',
#  'gornopravdinsk',
#  'yenagoa',
#  'phrai bung',
#  'hof',
#  'victor harbor',
#  'flinders',
#  'oranjemund',
#  'torbay',
#  'baoying',
#  'coquimbo',
#  'belaya gora',
#  'stolin',
#  'carauari',
#  'mys shmidta',
#  'basco',
#  'killarney',
#  'amos',
#  'honiara',
#  'senanga',
#  'vila velha',
#  'boende',
#  'lata',
#  'kushiro',
#  'bethel',
#  'perth',
#  'hwange',
#  'shugurovo',
#  'scottsburgh',
#  'pennagaram',
#  'maghama',
#  'turtkul',
#  'te anau',
#  'shikhany',
#  'iqaluit',
#  'jiuquan',
#  'larap',
#  'sitka',
#  'parrita',
#  'outlook',
#  'kuche',
#  'ust-karsk',
#  'yeppoon',
#  'lagoa',
#  'acapulco',
#  'havre-saint-pierre',
#  'mabaruma',
#  'henties bay',
#  'dingle',
#  'aktau',
#  'mahanoro',
#  'homer',
#  'genhe',
#  'bela',
#  'pisco',
#  'wahran',
#  'daru',
#  'san quintin',
#  'puerto escondido',
#  'saint-denis',
#  'barawe',
#  'samusu',
#  'kinsale',
#  'waw',
#  'povenets',
#  'talnakh',
#  'beloha',
#  'katherine',
#  'tuy hoa',
#  'longyearbyen',
#  'baragua',
#  'tamiahua',
#  'port blair',
#  'sangar',
#  'vila do maio',
#  'samarai',
#  'antsohihy',
#  'sibolga',
#  'jaciara',
#  'shiyan',
#  'vila',
#  'bossembele',
#  'novikovo',
#  'marfino',
#  'cururupu',
#  'bocas del toro',
#  'la palma',
#  'marv dasht',
#  'byumba',
#  'ocos',
#  'dinghai',
#  'san felipe',
#  'sioux lookout',
#  'jalu',
#  'barentsburg',
#  'umm lajj',
#  'beringovskiy',
#  'dekar',
#  'sinfra',
#  'miri',
#  'alice springs',
#  'golden',
#  'moose factory',
#  'la romana',
#  'yeniseysk',
#  'nouadhibou',
#  'altay',
#  'tucupita',
#  'srandakan',
#  'joshimath',
#  'pangnirtung',
#  'asyut',
#  'cherskiy',
#  'mahon',
#  'lewiston',
#  'dire dawa',
#  'labuhan',
#  'sept-iles',
#  'great falls',
#  'burnie',
#  'grand gaube',
#  'danielskuil',
#  'raga',
#  'ilulissat',
#  'ishigaki',
#  'kudahuvadhoo',
#  'khandyga',
#  'balkanabat',
#  'rawannawi',
#  'texarkana',
#  'tanout',
#  'hasaki',
#  'nanakuli',
#  'champerico',
#  'port hedland',
#  'storslett',
#  'muros',
#  'port lincoln',
#  'la ronge',
#  'cayenne',
#  'ambon',
#  'ossora',
#  'manado',
#  'havoysund',
#  'port macquarie',
#  'ahuas',
#  'ngukurr',
#  'nakamura',
#  'rocky mountain house',
#  'kaitangata',
#  'san cristobal',
#  'selma',
#  'tubruq',
#  'vestmannaeyjar',
#  'bambous virieux',
#  'london',
#  'jimenez',
#  'baharampur',
#  'nara',
#  'praia da vitoria',
#  'bargal',
#  'huangchuan',
#  'bocaiuva',
#  'indramayu',
#  'norman wells',
#  'inuvik',
#  'tambul',
#  'quelimane',
#  'brae',
#  'iwanai',
#  'dubbo',
#  'fortuna',
#  'paita',
#  'amahai',
#  'iquitos',
#  'raudeberg',
#  'butembo',
#  'taoudenni',
#  'mahaicony',
#  'kupang',
#  'veraval',
#  'yumen',
#  'batemans bay',
#  'scarborough',
#  'aktash',
#  'mitsamiouli',
#  'yirol',
#  'uaua',
#  'trincomalee',
#  'odweyne',
#  'kirakira',
#  'haines junction',
#  'asilah',
#  'tomatlan',
#  'navirai',
#  'mandera',
#  'prince george',
#  'palauig',
#  'rosario',
#  'barcelos',
#  'alotau',
#  'lemesos',
#  'silvan',
#  'kiunga',
#  'murgab',
#  'ruatoria',
#  'espera feliz',
#  'nisia floresta',
#  'mweka',
#  'port hueneme',
#  'muyezerskiy',
#  'catamarca',
#  'chandil',
#  'pafos',
#  'camara de lobos',
#  'huarmey',
#  'karpogory',
#  'kruisfontein',
#  'tselinnoye',
#  'koslan',
#  'gouyave',
#  'chimore',
#  'ulkan',
#  'avera',
#  'ningan',
#  'kranjska gora',
#  'artyk',
#  'piriyapatna',
#  'torgau',
#  'tutoia',
#  'salalah',
#  'san andres',
#  'luan',
#  'awbari',
#  'marystown',
#  'cabedelo',
#  'kerrville',
#  'careiro da varzea',
#  'stornoway',
#  'itarema',
#  'hirado',
#  'arrecife',
#  'komsomolskiy',
#  'najran',
#  'maua',
#  'pangkalanbuun',
#  'monrovia',
#  'palabuhanratu',
#  'edea',
#  'kieta',
#  'hualmay',
#  'meyungs',
#  'dyersburg',
#  'tarko-sale',
#  'kerouane',
#  'belmonte',
#  'ixtapa',
#  'stoyba',
#  'inhambane',
#  'mwense',
#  'bardsir',
#  'comodoro rivadavia',
#  'inirida',
#  'redmond',
#  'gravdal',
#  'vaitupu',
#  'utiroa',
#  'dubuque',
#  'plettenberg bay',
#  'monte mor',
#  'turinsk',
#  'miracema do tocantins',
#  'saint-pierre',
#  'dicabisagan',
#  'puerto pinasco',
#  'kotido',
#  'buala',
#  'manavalakurichi',
#  'shelburne',
#  'voznesenye',
#  'olinda',
#  'mount isa',
#  'taicheng',
#  'marcona',
#  'svetlyy',
#  'krasnyy chikoy',
#  'sierra vista',
#  'aki',
#  'naze',
#  'sohag',
#  'dombarovskiy',
#  'solnechnyy',
#  'gayny',
#  'tabiauea',
#  'huangzhai',
#  'xiaoweizhai',
#  'qaqortoq',
#  'luancheng',
#  'waingapu',
#  'suruc',
#  'hailar',
#  'ornskoldsvik',
#  'makakilo city',
#  'banda aceh',
#  'riga',
#  'deputatskiy',
#  'tairua',
#  'fevralsk',
#  'slave lake',
#  'pacific grove',
#  'cairo',
#  'kenai',
#  'san lawrenz',
#  'hambantota',
#  'santa cruz del sur',
#  'oyabe',
#  'opotiki',
#  'kansanshi',
#  'maple creek',
#  'karratha',
#  'omsukchan',
#  'davila',
#  'otjiwarongo',
#  'mabayo',
#  'mananjary',
#  'abu dhabi',
#  'kasane',
#  'bend',
#  'molepolole',
#  'adrar',
#  'suao',
#  'sanming',
#  'acari',
#  'karkaralinsk',
#  'yablochnyy',
#  'bilma',
#  'san giovanni valdarno',
#  'sambava']

# %% [markdown]
# ### Perform API Calls

# %%
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []
counter = 0


for city in cities:
    print("--------------")
    print(f' Processing request of the city {city}') 
    url = (f'https://api.openweathermap.org/data/2.5/weather?q={city}&units=imperial&appid={weather_api_key}')
    weather_response = requests.get(url)
    weather_json = weather_response.json()

    try:
        cloudiness.append(weather_json['clouds']['all'])
        country.append(weather_json['sys']['country'])
        date.append(weather_json['dt'])
        humidity.append(weather_json['main']['humidity'])
        lat.append(weather_json['coord']['lat'])
        lng.append(weather_json['coord']['lon'])
        max_temp.append(weather_json['main']['temp_max'])
        wind_speed.append(weather_json['wind']['speed'])
    except:
        print("city not found. skipping...")
        cloudiness.append('NaN')
        country.append('NaN')
        date.append('NaN')
        humidity.append('NaN')
        lat.append('NaN')
        lng.append('NaN')
        max_temp.append('NaN')
        wind_speed.append('NaN')
# Out:
# --------------
#  Processing request of the city georgetown
# --------------
#  Processing request of the city tuktoyaktuk
# --------------
#  Processing request of the city upernavik
# --------------
#  Processing request of the city paamiut
# --------------
#  Processing request of the city port elizabeth
# --------------
#  Processing request of the city taolanaro
# city not found. skipping...
# --------------
#  Processing request of the city butaritari
# --------------
#  Processing request of the city tsihombe
# city not found. skipping...
# --------------
#  Processing request of the city khatanga
# --------------
#  Processing request of the city vaini
# --------------
#  Processing request of the city cassilandia
# --------------
#  Processing request of the city boa vista
# --------------
#  Processing request of the city illoqqortoormiut
# city not found. skipping...
# --------------
#  Processing request of the city saskylakh
# --------------
#  Processing request of the city beira
# --------------
#  Processing request of the city simdega
# --------------
#  Processing request of the city rikitea
# --------------
#  Processing request of the city takoradi
# --------------
#  Processing request of the city mahebourg
# --------------
#  Processing request of the city cape town
# --------------
#  Processing request of the city nikolskoye
# --------------
#  Processing request of the city albany
# --------------
#  Processing request of the city ponta do sol
# --------------
#  Processing request of the city noto
# --------------
#  Processing request of the city thompson
# --------------
#  Processing request of the city mosetse
# --------------
#  Processing request of the city attawapiskat
# city not found. skipping...
# --------------
#  Processing request of the city castro
# --------------
#  Processing request of the city caravelas
# --------------
#  Processing request of the city surgana
# --------------
#  Processing request of the city carnarvon
# --------------
#  Processing request of the city tateyama
# --------------
#  Processing request of the city kwekwe
# --------------
#  Processing request of the city provideniya
# --------------
#  Processing request of the city airai
# --------------
#  Processing request of the city verkhnevilyuysk
# --------------
#  Processing request of the city mar del plata
# --------------
#  Processing request of the city hermanus
# --------------
#  Processing request of the city namibe
# --------------
#  Processing request of the city baracoa
# --------------
#  Processing request of the city grand river south east
# city not found. skipping...
# --------------
#  Processing request of the city shimanovsk
# --------------
#  Processing request of the city atar
# --------------
#  Processing request of the city bindura
# --------------
#  Processing request of the city santa fe
# --------------
#  Processing request of the city touros
# --------------
#  Processing request of the city vilhena
# --------------
#  Processing request of the city damavand
# --------------
#  Processing request of the city belushya guba
# city not found. skipping...
# --------------
#  Processing request of the city geraldton
# --------------
#  Processing request of the city esperance
# --------------
#  Processing request of the city asfi
# --------------
#  Processing request of the city chuy
# --------------
#  Processing request of the city ushuaia
# --------------
#  Processing request of the city ola
# --------------
#  Processing request of the city tiarei
# --------------
#  Processing request of the city miramar
# --------------
#  Processing request of the city salo
# --------------
#  Processing request of the city tiksi
# --------------
#  Processing request of the city gubkinskiy
# --------------
#  Processing request of the city punta arenas
# --------------
#  Processing request of the city greenville
# --------------
#  Processing request of the city bambanglipuro
# --------------
#  Processing request of the city cabo san lucas
# --------------
#  Processing request of the city coihaique
# --------------
#  Processing request of the city ribeira grande
# --------------
#  Processing request of the city sinnamary
# --------------
#  Processing request of the city arraial do cabo
# --------------
#  Processing request of the city atuona
# --------------
#  Processing request of the city longlac
# city not found. skipping...
# --------------
#  Processing request of the city saint george
# --------------
#  Processing request of the city padang
# --------------
#  Processing request of the city amurzet
# --------------
#  Processing request of the city oktyabrskoye
# --------------
#  Processing request of the city bluff
# --------------
#  Processing request of the city puerto baquerizo moreno
# --------------
#  Processing request of the city kalmunai
# --------------
#  Processing request of the city puerto ayora
# --------------
#  Processing request of the city pemba
# --------------
#  Processing request of the city cap malheureux
# --------------
#  Processing request of the city kapaa
# --------------
#  Processing request of the city port alfred
# --------------
#  Processing request of the city mataura
# --------------
#  Processing request of the city hilo
# --------------
#  Processing request of the city port hardy
# --------------
#  Processing request of the city mount gambier
# --------------
#  Processing request of the city emerald
# --------------
#  Processing request of the city luganville
# --------------
#  Processing request of the city walvis bay
# --------------
#  Processing request of the city muroto
# --------------
#  Processing request of the city lithgow
# --------------
#  Processing request of the city myaundzha
# --------------
#  Processing request of the city tuim
# --------------
#  Processing request of the city kondinskoye
# --------------
#  Processing request of the city biak
# --------------
#  Processing request of the city zelenogorskiy
# --------------
#  Processing request of the city cidreira
# --------------
#  Processing request of the city baruun-urt
# --------------
#  Processing request of the city olafsvik
# --------------
#  Processing request of the city tasiilaq
# --------------
#  Processing request of the city mentok
# city not found. skipping...
# --------------
#  Processing request of the city faya
# --------------
#  Processing request of the city grindavik
# --------------
#  Processing request of the city dikson
# --------------
#  Processing request of the city spornoye
# --------------
#  Processing request of the city puerto palomas
# --------------
#  Processing request of the city uwayl
# city not found. skipping...
# --------------
#  Processing request of the city saldanha
# --------------
#  Processing request of the city jacqueville
# --------------
#  Processing request of the city puerto carreno
# --------------
#  Processing request of the city asau
# --------------
#  Processing request of the city johi
# --------------
#  Processing request of the city le vauclin
# --------------
#  Processing request of the city bagamoyo
# --------------
#  Processing request of the city petropavlovsk-kamchatskiy
# --------------
#  Processing request of the city koumac
# --------------
#  Processing request of the city codrington
# --------------
#  Processing request of the city campoverde
# --------------
#  Processing request of the city eyl
# --------------
#  Processing request of the city lavrentiya
# --------------
#  Processing request of the city tuatapere
# --------------
#  Processing request of the city bandarbeyla
# --------------
#  Processing request of the city casablanca
# --------------
#  Processing request of the city hovd
# --------------
#  Processing request of the city kununurra
# --------------
#  Processing request of the city gyomaendrod
# --------------
#  Processing request of the city bintulu
# --------------
#  Processing request of the city aguimes
# --------------
#  Processing request of the city poum
# --------------
#  Processing request of the city saleaula
# city not found. skipping...
# --------------
#  Processing request of the city gimli
# --------------
#  Processing request of the city bredasdorp
# --------------
#  Processing request of the city bathsheba
# --------------
#  Processing request of the city saint-georges
# --------------
#  Processing request of the city liwale
# --------------
#  Processing request of the city avarua
# --------------
#  Processing request of the city wulanhaote
# city not found. skipping...
# --------------
#  Processing request of the city yulara
# --------------
#  Processing request of the city vanimo
# --------------
#  Processing request of the city severo-kurilsk
# --------------
#  Processing request of the city victoria
# --------------
#  Processing request of the city sao joao da barra
# --------------
#  Processing request of the city sungai siput utara
# city not found. skipping...
# --------------
#  Processing request of the city chapais
# --------------
#  Processing request of the city kodiak
# --------------
#  Processing request of the city torres
# --------------
#  Processing request of the city rolim de moura
# city not found. skipping...
# --------------
#  Processing request of the city yellowknife
# --------------
#  Processing request of the city sakassou
# --------------
#  Processing request of the city nizhneyansk
# city not found. skipping...
# --------------
#  Processing request of the city rio verde de mato grosso
# --------------
#  Processing request of the city san patricio
# --------------
#  Processing request of the city khurai
# --------------
#  Processing request of the city ancud
# --------------
#  Processing request of the city irbeyskoye
# --------------
#  Processing request of the city isangel
# --------------
#  Processing request of the city pevek
# --------------
#  Processing request of the city kavieng
# --------------
#  Processing request of the city fairbanks
# --------------
#  Processing request of the city urumqi
# --------------
#  Processing request of the city vostok
# --------------
#  Processing request of the city pasni
# --------------
#  Processing request of the city turbat
# --------------
#  Processing request of the city lebu
# --------------
#  Processing request of the city vao
# --------------
#  Processing request of the city loviisa
# --------------
#  Processing request of the city east london
# --------------
#  Processing request of the city hobart
# --------------
#  Processing request of the city tessalit
# --------------
#  Processing request of the city kazalinsk
# city not found. skipping...
# --------------
#  Processing request of the city urdzhar
# city not found. skipping...
# --------------
#  Processing request of the city longfeng
# --------------
#  Processing request of the city qaanaaq
# --------------
#  Processing request of the city ambovombe
# --------------
#  Processing request of the city barrow
# --------------
#  Processing request of the city mehamn
# --------------
#  Processing request of the city itambacuri
# --------------
#  Processing request of the city tabou
# --------------
#  Processing request of the city palmer
# --------------
#  Processing request of the city hofn
# --------------
#  Processing request of the city cloquet
# --------------
#  Processing request of the city pizhanka
# --------------
#  Processing request of the city louisbourg
# city not found. skipping...
# --------------
#  Processing request of the city bengkulu
# --------------
#  Processing request of the city guerrero negro
# --------------
#  Processing request of the city egvekinot
# --------------
#  Processing request of the city laguna
# --------------
#  Processing request of the city alofi
# --------------
#  Processing request of the city shunyi
# --------------
#  Processing request of the city bima
# --------------
#  Processing request of the city narsaq
# --------------
#  Processing request of the city santa ana
# --------------
#  Processing request of the city klaksvik
# --------------
#  Processing request of the city los llanos de aridane
# --------------
#  Processing request of the city ponyri
# --------------
#  Processing request of the city ayotzingo
# city not found. skipping...
# --------------
#  Processing request of the city mitchell
# --------------
#  Processing request of the city jamestown
# --------------
#  Processing request of the city methoni
# --------------
#  Processing request of the city ambilobe
# --------------
#  Processing request of the city bonavista
# --------------
#  Processing request of the city saint-philippe
# --------------
#  Processing request of the city meulaboh
# --------------
#  Processing request of the city hutchinson
# --------------
#  Processing request of the city sentyabrskiy
# city not found. skipping...
# --------------
#  Processing request of the city qasigiannguit
# --------------
#  Processing request of the city gat
# --------------
#  Processing request of the city bolungarvik
# city not found. skipping...
# --------------
#  Processing request of the city antofagasta
# --------------
#  Processing request of the city saint-francois
# --------------
#  Processing request of the city bien hoa
# --------------
#  Processing request of the city spas-klepiki
# --------------
#  Processing request of the city port augusta
# --------------
#  Processing request of the city diego de almagro
# --------------
#  Processing request of the city leshukonskoye
# --------------
#  Processing request of the city ponta delgada
# --------------
#  Processing request of the city hithadhoo
# --------------
#  Processing request of the city teacapan
# --------------
#  Processing request of the city marabba
# --------------
#  Processing request of the city hobyo
# --------------
#  Processing request of the city nueve de julio
# --------------
#  Processing request of the city mayya
# --------------
#  Processing request of the city constitucion
# --------------
#  Processing request of the city excelsior springs
# --------------
#  Processing request of the city virginia beach
# --------------
#  Processing request of the city haapiti
# --------------
#  Processing request of the city busselton
# --------------
#  Processing request of the city micheweni
# --------------
#  Processing request of the city amderma
# city not found. skipping...
# --------------
#  Processing request of the city jacmel
# --------------
#  Processing request of the city karaul
# city not found. skipping...
# --------------
#  Processing request of the city faanui
# --------------
#  Processing request of the city balimo
# city not found. skipping...
# --------------
#  Processing request of the city tomohon
# --------------
#  Processing request of the city villafranca de los barros
# --------------
#  Processing request of the city marathon
# --------------
#  Processing request of the city chokurdakh
# --------------
#  Processing request of the city nagapattinam
# --------------
#  Processing request of the city seoul
# --------------
#  Processing request of the city klyuchi
# --------------
#  Processing request of the city wukari
# --------------
#  Processing request of the city bafra
# --------------
#  Processing request of the city bo phloi
# --------------
#  Processing request of the city skagastrond
# city not found. skipping...
# --------------
#  Processing request of the city uglovka
# --------------
#  Processing request of the city new norfolk
# --------------
#  Processing request of the city shingu
# --------------
#  Processing request of the city port moresby
# --------------
#  Processing request of the city bilibino
# --------------
#  Processing request of the city luderitz
# --------------
#  Processing request of the city kahului
# --------------
#  Processing request of the city kariba
# --------------
#  Processing request of the city ternate
# --------------
#  Processing request of the city leningradskiy
# --------------
#  Processing request of the city goma
# --------------
#  Processing request of the city nhulunbuy
# --------------
#  Processing request of the city noumea
# --------------
#  Processing request of the city filadelfia
# --------------
#  Processing request of the city arlit
# --------------
#  Processing request of the city magdagachi
# --------------
#  Processing request of the city lompoc
# --------------
#  Processing request of the city conakry
# --------------
#  Processing request of the city vaitape
# --------------
#  Processing request of the city margate
# --------------
#  Processing request of the city aubenas
# --------------
#  Processing request of the city lahat
# --------------
#  Processing request of the city katsuura
# --------------
#  Processing request of the city itoman
# --------------
#  Processing request of the city lufilufi
# --------------
#  Processing request of the city saint-augustin
# --------------
#  Processing request of the city abu samrah
# --------------
#  Processing request of the city udachnyy
# --------------
#  Processing request of the city shitanjing
# --------------
#  Processing request of the city betafo
# --------------
#  Processing request of the city maragogi
# --------------
#  Processing request of the city elmira
# --------------
#  Processing request of the city quatre cocos
# --------------
#  Processing request of the city sao jose da coroa grande
# --------------
#  Processing request of the city tiznit
# --------------
#  Processing request of the city gonzales
# --------------
#  Processing request of the city batu
# --------------
#  Processing request of the city hamilton
# --------------
#  Processing request of the city nanortalik
# --------------
#  Processing request of the city souillac
# --------------
#  Processing request of the city goderich
# --------------
#  Processing request of the city myanaung
# --------------
#  Processing request of the city zlatibor
# --------------
#  Processing request of the city gornopravdinsk
# --------------
#  Processing request of the city yenagoa
# --------------
#  Processing request of the city phrai bung
# city not found. skipping...
# --------------
#  Processing request of the city hof
# --------------
#  Processing request of the city victor harbor
# --------------
#  Processing request of the city flinders
# --------------
#  Processing request of the city oranjemund
# --------------
#  Processing request of the city torbay
# --------------
#  Processing request of the city baoying
# --------------
#  Processing request of the city coquimbo
# --------------
#  Processing request of the city belaya gora
# --------------
#  Processing request of the city stolin
# --------------
#  Processing request of the city carauari
# --------------
#  Processing request of the city mys shmidta
# city not found. skipping...
# --------------
#  Processing request of the city basco
# --------------
#  Processing request of the city killarney
# --------------
#  Processing request of the city amos
# --------------
#  Processing request of the city honiara
# --------------
#  Processing request of the city senanga
# --------------
#  Processing request of the city vila velha
# --------------
#  Processing request of the city boende
# --------------
#  Processing request of the city lata
# --------------
#  Processing request of the city kushiro
# --------------
#  Processing request of the city bethel
# --------------
#  Processing request of the city perth
# --------------
#  Processing request of the city hwange
# --------------
#  Processing request of the city shugurovo
# --------------
#  Processing request of the city scottsburgh
# city not found. skipping...
# --------------
#  Processing request of the city pennagaram
# --------------
#  Processing request of the city maghama
# city not found. skipping...
# --------------
#  Processing request of the city turtkul
# city not found. skipping...
# --------------
#  Processing request of the city te anau
# --------------
#  Processing request of the city shikhany
# --------------
#  Processing request of the city iqaluit
# --------------
#  Processing request of the city jiuquan
# --------------
#  Processing request of the city larap
# --------------
#  Processing request of the city sitka
# --------------
#  Processing request of the city parrita
# --------------
#  Processing request of the city outlook
# --------------
#  Processing request of the city kuche
# city not found. skipping...
# --------------
#  Processing request of the city ust-karsk
# --------------
#  Processing request of the city yeppoon
# --------------
#  Processing request of the city lagoa
# --------------
#  Processing request of the city acapulco
# --------------
#  Processing request of the city havre-saint-pierre
# --------------
#  Processing request of the city mabaruma
# --------------
#  Processing request of the city henties bay
# --------------
#  Processing request of the city dingle
# --------------
#  Processing request of the city aktau
# --------------
#  Processing request of the city mahanoro
# --------------
#  Processing request of the city homer
# --------------
#  Processing request of the city genhe
# --------------
#  Processing request of the city bela
# --------------
#  Processing request of the city pisco
# --------------
#  Processing request of the city wahran
# city not found. skipping...
# --------------
#  Processing request of the city daru
# --------------
#  Processing request of the city san quintin
# --------------
#  Processing request of the city puerto escondido
# --------------
#  Processing request of the city saint-denis
# --------------
#  Processing request of the city barawe
# city not found. skipping...
# --------------
#  Processing request of the city samusu
# city not found. skipping...
# --------------
#  Processing request of the city kinsale
# --------------
#  Processing request of the city waw
# --------------
#  Processing request of the city povenets
# --------------
#  Processing request of the city talnakh
# --------------
#  Processing request of the city beloha
# --------------
#  Processing request of the city katherine
# --------------
#  Processing request of the city tuy hoa
# --------------
#  Processing request of the city longyearbyen
# --------------
#  Processing request of the city baragua
# --------------
#  Processing request of the city tamiahua
# --------------
#  Processing request of the city port blair
# --------------
#  Processing request of the city sangar
# --------------
#  Processing request of the city vila do maio
# --------------
#  Processing request of the city samarai
# --------------
#  Processing request of the city antsohihy
# --------------
#  Processing request of the city sibolga
# --------------
#  Processing request of the city jaciara
# --------------
#  Processing request of the city shiyan
# --------------
#  Processing request of the city vila
# --------------
#  Processing request of the city bossembele
# city not found. skipping...
# --------------
#  Processing request of the city novikovo
# --------------
#  Processing request of the city marfino
# --------------
#  Processing request of the city cururupu
# --------------
#  Processing request of the city bocas del toro
# --------------
#  Processing request of the city la palma
# --------------
#  Processing request of the city marv dasht
# city not found. skipping...
# --------------
#  Processing request of the city byumba
# --------------
#  Processing request of the city ocos
# --------------
#  Processing request of the city dinghai
# --------------
#  Processing request of the city san felipe
# --------------
#  Processing request of the city sioux lookout
# --------------
#  Processing request of the city jalu
# --------------
#  Processing request of the city barentsburg
# city not found. skipping...
# --------------
#  Processing request of the city umm lajj
# --------------
#  Processing request of the city beringovskiy
# --------------
#  Processing request of the city dekar
# --------------
#  Processing request of the city sinfra
# --------------
#  Processing request of the city miri
# --------------
#  Processing request of the city alice springs
# --------------
#  Processing request of the city golden
# --------------
#  Processing request of the city moose factory
# --------------
#  Processing request of the city la romana
# --------------
#  Processing request of the city yeniseysk
# --------------
#  Processing request of the city nouadhibou
# --------------
#  Processing request of the city altay
# --------------
#  Processing request of the city tucupita
# --------------
#  Processing request of the city srandakan
# --------------
#  Processing request of the city joshimath
# --------------
#  Processing request of the city pangnirtung
# --------------
#  Processing request of the city asyut
# --------------
#  Processing request of the city cherskiy
# --------------
#  Processing request of the city mahon
# --------------
#  Processing request of the city lewiston
# --------------
#  Processing request of the city dire dawa
# --------------
#  Processing request of the city labuhan
# --------------
#  Processing request of the city sept-iles
# --------------
#  Processing request of the city great falls
# --------------
#  Processing request of the city burnie
# --------------
#  Processing request of the city grand gaube
# --------------
#  Processing request of the city danielskuil
# --------------
#  Processing request of the city raga
# --------------
#  Processing request of the city ilulissat
# --------------
#  Processing request of the city ishigaki
# --------------
#  Processing request of the city kudahuvadhoo
# --------------
#  Processing request of the city khandyga
# --------------
#  Processing request of the city balkanabat
# --------------
#  Processing request of the city rawannawi
# city not found. skipping...
# --------------
#  Processing request of the city texarkana
# --------------
#  Processing request of the city tanout
# --------------
#  Processing request of the city hasaki
# --------------
#  Processing request of the city nanakuli
# --------------
#  Processing request of the city champerico
# --------------
#  Processing request of the city port hedland
# --------------
#  Processing request of the city storslett
# --------------
#  Processing request of the city muros
# --------------
#  Processing request of the city port lincoln
# --------------
#  Processing request of the city la ronge
# --------------
#  Processing request of the city cayenne
# --------------
#  Processing request of the city ambon
# --------------
#  Processing request of the city ossora
# --------------
#  Processing request of the city manado
# --------------
#  Processing request of the city havoysund
# --------------
#  Processing request of the city port macquarie
# --------------
#  Processing request of the city ahuas
# --------------
#  Processing request of the city ngukurr
# city not found. skipping...
# --------------
#  Processing request of the city nakamura
# --------------
#  Processing request of the city rocky mountain house
# --------------
#  Processing request of the city kaitangata
# --------------
#  Processing request of the city san cristobal
# --------------
#  Processing request of the city selma
# --------------
#  Processing request of the city tubruq
# city not found. skipping...
# --------------
#  Processing request of the city vestmannaeyjar
# --------------
#  Processing request of the city bambous virieux
# --------------
#  Processing request of the city london
# --------------
#  Processing request of the city jimenez
# --------------
#  Processing request of the city baharampur
# --------------
#  Processing request of the city nara
# --------------
#  Processing request of the city praia da vitoria
# --------------
#  Processing request of the city bargal
# city not found. skipping...
# --------------
#  Processing request of the city huangchuan
# --------------
#  Processing request of the city bocaiuva
# --------------
#  Processing request of the city indramayu
# --------------
#  Processing request of the city norman wells
# --------------
#  Processing request of the city inuvik
# --------------
#  Processing request of the city tambul
# city not found. skipping...
# --------------
#  Processing request of the city quelimane
# --------------
#  Processing request of the city brae
# --------------
#  Processing request of the city iwanai
# --------------
#  Processing request of the city dubbo
# --------------
#  Processing request of the city fortuna
# --------------
#  Processing request of the city paita
# --------------
#  Processing request of the city amahai
# --------------
#  Processing request of the city iquitos
# --------------
#  Processing request of the city raudeberg
# --------------
#  Processing request of the city butembo
# --------------
#  Processing request of the city taoudenni
# --------------
#  Processing request of the city mahaicony
# city not found. skipping...
# --------------
#  Processing request of the city kupang
# --------------
#  Processing request of the city veraval
# --------------
#  Processing request of the city yumen
# --------------
#  Processing request of the city batemans bay
# --------------
#  Processing request of the city scarborough
# --------------
#  Processing request of the city aktash
# --------------
#  Processing request of the city mitsamiouli
# --------------
#  Processing request of the city yirol
# city not found. skipping...
# --------------
#  Processing request of the city uaua
# --------------
#  Processing request of the city trincomalee
# --------------
#  Processing request of the city odweyne
# --------------
#  Processing request of the city kirakira
# --------------
#  Processing request of the city haines junction
# --------------
#  Processing request of the city asilah
# --------------
#  Processing request of the city tomatlan
# --------------
#  Processing request of the city navirai
# --------------
#  Processing request of the city mandera
# --------------
#  Processing request of the city prince george
# --------------
#  Processing request of the city palauig
# --------------
#  Processing request of the city rosario
# --------------
#  Processing request of the city barcelos
# --------------
#  Processing request of the city alotau
# city not found. skipping...
# --------------
#  Processing request of the city lemesos
# city not found. skipping...
# --------------
#  Processing request of the city silvan
# --------------
#  Processing request of the city kiunga
# --------------
#  Processing request of the city murgab
# --------------
#  Processing request of the city ruatoria
# city not found. skipping...
# --------------
#  Processing request of the city espera feliz
# --------------
#  Processing request of the city nisia floresta
# --------------
#  Processing request of the city mweka
# --------------
#  Processing request of the city port hueneme
# --------------
#  Processing request of the city muyezerskiy
# --------------
#  Processing request of the city catamarca
# --------------
#  Processing request of the city chandil
# --------------
#  Processing request of the city pafos
# --------------
#  Processing request of the city camara de lobos
# --------------
#  Processing request of the city huarmey
# --------------
#  Processing request of the city karpogory
# --------------
#  Processing request of the city kruisfontein
# --------------
#  Processing request of the city tselinnoye
# --------------
#  Processing request of the city koslan
# --------------
#  Processing request of the city gouyave
# --------------
#  Processing request of the city chimore
# --------------
#  Processing request of the city ulkan
# --------------
#  Processing request of the city avera
# --------------
#  Processing request of the city ningan
# city not found. skipping...
# --------------
#  Processing request of the city kranjska gora
# --------------
#  Processing request of the city artyk
# city not found. skipping...
# --------------
#  Processing request of the city piriyapatna
# --------------
#  Processing request of the city torgau
# --------------
#  Processing request of the city tutoia
# --------------
#  Processing request of the city salalah
# --------------
#  Processing request of the city san andres
# --------------
#  Processing request of the city luan
# --------------
#  Processing request of the city awbari
# --------------
#  Processing request of the city marystown
# --------------
#  Processing request of the city cabedelo
# --------------
#  Processing request of the city kerrville
# --------------
#  Processing request of the city careiro da varzea
# --------------
#  Processing request of the city stornoway
# --------------
#  Processing request of the city itarema
# --------------
#  Processing request of the city hirado
# --------------
#  Processing request of the city arrecife
# --------------
#  Processing request of the city komsomolskiy
# --------------
#  Processing request of the city najran
# --------------
#  Processing request of the city maua
# --------------
#  Processing request of the city pangkalanbuun
# --------------
#  Processing request of the city monrovia
# --------------
#  Processing request of the city palabuhanratu
# city not found. skipping...
# --------------
#  Processing request of the city edea
# --------------
#  Processing request of the city kieta
# --------------
#  Processing request of the city hualmay
# --------------
#  Processing request of the city meyungs
# city not found. skipping...
# --------------
#  Processing request of the city dyersburg
# --------------
#  Processing request of the city tarko-sale
# --------------
#  Processing request of the city kerouane
# --------------
#  Processing request of the city belmonte
# --------------
#  Processing request of the city ixtapa
# --------------
#  Processing request of the city stoyba
# city not found. skipping...
# --------------
#  Processing request of the city inhambane
# --------------
#  Processing request of the city mwense
# --------------
#  Processing request of the city bardsir
# --------------
#  Processing request of the city comodoro rivadavia
# --------------
#  Processing request of the city inirida
# --------------
#  Processing request of the city redmond
# --------------
#  Processing request of the city gravdal
# --------------
#  Processing request of the city vaitupu
# city not found. skipping...
# --------------
#  Processing request of the city utiroa
# city not found. skipping...
# --------------
#  Processing request of the city dubuque
# --------------
#  Processing request of the city plettenberg bay
# --------------
#  Processing request of the city monte mor
# --------------
#  Processing request of the city turinsk
# --------------
#  Processing request of the city miracema do tocantins
# --------------
#  Processing request of the city saint-pierre
# --------------
#  Processing request of the city dicabisagan
# --------------
#  Processing request of the city puerto pinasco
# city not found. skipping...
# --------------
#  Processing request of the city kotido
# --------------
#  Processing request of the city buala
# --------------
#  Processing request of the city manavalakurichi
# --------------
#  Processing request of the city shelburne
# --------------
#  Processing request of the city voznesenye
# --------------
#  Processing request of the city olinda
# --------------
#  Processing request of the city mount isa
# --------------
#  Processing request of the city taicheng
# --------------
#  Processing request of the city marcona
# city not found. skipping...
# --------------
#  Processing request of the city svetlyy
# --------------
#  Processing request of the city krasnyy chikoy
# --------------
#  Processing request of the city sierra vista
# --------------
#  Processing request of the city aki
# --------------
#  Processing request of the city naze
# --------------
#  Processing request of the city sohag
# --------------
#  Processing request of the city dombarovskiy
# --------------
#  Processing request of the city solnechnyy
# --------------
#  Processing request of the city gayny
# --------------
#  Processing request of the city tabiauea
# city not found. skipping...
# --------------
#  Processing request of the city huangzhai
# --------------
#  Processing request of the city xiaoweizhai
# --------------
#  Processing request of the city qaqortoq
# --------------
#  Processing request of the city luancheng
# --------------
#  Processing request of the city waingapu
# --------------
#  Processing request of the city suruc
# --------------
#  Processing request of the city hailar
# --------------
#  Processing request of the city ornskoldsvik
# --------------
#  Processing request of the city makakilo city
# --------------
#  Processing request of the city banda aceh
# --------------
#  Processing request of the city riga
# --------------
#  Processing request of the city deputatskiy
# --------------
#  Processing request of the city tairua
# --------------
#  Processing request of the city fevralsk
# city not found. skipping...
# --------------
#  Processing request of the city slave lake
# --------------
#  Processing request of the city pacific grove
# --------------
#  Processing request of the city cairo
# --------------
#  Processing request of the city kenai
# --------------
#  Processing request of the city san lawrenz
# --------------
#  Processing request of the city hambantota
# --------------
#  Processing request of the city santa cruz del sur
# --------------
#  Processing request of the city oyabe
# --------------
#  Processing request of the city opotiki
# --------------
#  Processing request of the city kansanshi
# --------------
#  Processing request of the city maple creek
# --------------
#  Processing request of the city karratha
# --------------
#  Processing request of the city omsukchan
# --------------
#  Processing request of the city davila
# --------------
#  Processing request of the city otjiwarongo
# --------------
#  Processing request of the city mabayo
# --------------
#  Processing request of the city mananjary
# --------------
#  Processing request of the city abu dhabi
# --------------
#  Processing request of the city kasane
# --------------
#  Processing request of the city bend
# --------------
#  Processing request of the city molepolole
# --------------
#  Processing request of the city adrar
# --------------
#  Processing request of the city suao
# city not found. skipping...
# --------------
#  Processing request of the city sanming
# --------------
#  Processing request of the city acari
# --------------
#  Processing request of the city karkaralinsk
# city not found. skipping...
# --------------
#  Processing request of the city yablochnyy
# --------------
#  Processing request of the city bilma
# --------------
#  Processing request of the city san giovanni valdarno
# --------------
#  Processing request of the city sambava

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.

# %%
weather_check = pd.DataFrame({'City': cities, 'Cloudiness': cloudiness, 'Country': country, 'Date': date, 'Humidity': humidity, 'Latitude': lat, 'Longitude': lng, 'Max Temp': max_temp, 'Wind Speed': wind_speed})
weather_checkdf = weather_check[weather_check['Date'] != "NaN"]

weather_checkdf

weather_checknew = weather_checkdf.astype({'City': 'str', 'Cloudiness': 'float64', 'Country': 'str', 'Humidity': 'float64', 'Latitude': 'float64', 'Longitude': 'float64', 'Max Temp': 'float64', 'Wind Speed': 'float64'})
weather_checknew.to_csv("Output/WeatherCheck.csv", index=False, header=True)

# %% [markdown]
# ### Plotting the Data
# Check to see if there is relations between the different aspects location and weather conditions

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
lat = weather_checknew['Latitude']
temp = weather_checknew['Max Temp']
date = dt.datetime.today().strftime("%m/%d/%Y")


plt.scatter(lat, temp, marker="o", facecolors="red", edgecolors="black", alpha=0.75)
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (Farenheit)')
plt.title(f'Latitue vs. Max Temperature ({date})')
plt.grid()
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
hum = weather_checknew['Humidity']

plt.scatter(lat, hum, marker="o", facecolors="red", edgecolors="black", alpha=0.75)
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title(f'Latitue vs. Humidity ({date})')
plt.grid()
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
cloud = weather_checknew['Cloudiness']

plt.scatter(lat, cloud, marker="o", facecolors="red", edgecolors="black", alpha=0.75)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title(f'Latitue vs. Cloudiness ({date})')
plt.grid()
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
wind = weather_checknew['Wind Speed']

plt.scatter(lat, wind, marker="o", facecolors="red", edgecolors="black", alpha=0.75)
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (miles/hour)')
plt.title(f'Latitue vs. Wind Speed ({date})')
plt.grid()
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
from scipy.stats import linregress


def plotregress(xvalues, yvalues, textloc, ylabel):\
    #xvalues = are the values on the x axis
    #yvalues = are the values on the y axis
    #textloc = locations of the annotation
    # ylabel = the ylabel of the graph
    (slope, intercept, rvalue, pvalue, stderr) = linregress(xvalues, yvalues)
    regress_values = xvalues * slope + intercept
    plt.plot(xvalues,regress_values,"r-")
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.annotate(line_eq, textloc, fontsize=15, color="red")
    plt.ylabel(ylabel) 
    print(f"The r-squared is: {rvalue**2}")

# %%
# Create Northern and Southern Hemisphere DataFrames
north_weather_data = weather_checknew[weather_checknew['Latitude'] > 0]
south_weather_data = weather_checknew[weather_checknew['Latitude'] < 0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
nlat = north_weather_data['Latitude']
ntemp = north_weather_data['Max Temp']
date = dt.datetime.today().strftime("%m/%d/%Y")


plt.scatter(nlat, ntemp, marker="o", facecolors="blue", edgecolors="black", alpha=0.75)
plt.xlabel('Latitude')
plt.title(f'Northern Hemisphere Latitue vs. Max Temperature ({date})')
plotregress(nlat, ntemp, (5, 10), 'Max Temperature' )
plt.show()
# Out:
# The r-squared is: 0.6828740678408605

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
slat = south_weather_data['Latitude']
stemp = south_weather_data['Max Temp']
date = dt.datetime.today().strftime("%m/%d/%Y")


plt.scatter(slat, stemp, marker="o", facecolors="blue", edgecolors="black", alpha=0.75)
plt.xlabel('Latitude')
plt.title(f'Southern Hemisphere Latitue vs. Max Temperature ({date})')
plotregress(slat, stemp, (-30, 50), 'Max Temperature')
plt.show()
# Out:
# The r-squared is: 0.48987185369140873

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
nhum = north_weather_data['Humidity']
date = dt.datetime.today().strftime("%m/%d/%Y")


plt.scatter(nlat, nhum, marker="o", facecolors="blue", edgecolors="black", alpha=0.75)
plt.xlabel('Latitude')
plt.title(f'Northern Hemisphere Latitue vs. Humidity ({date})')
plotregress(nlat, nhum, (45, 10) , 'Humidity')
plt.show()
# Out:
# The r-squared is: 0.011187447692408169

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
shum = south_weather_data['Humidity']
date = dt.datetime.today().strftime("%m/%d/%Y")


plt.scatter(slat, shum, marker="o", facecolors="blue", edgecolors="black", alpha=0.75)
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title(f'Southern Hemisphere Latitue vs. Humidity ({date})')
plotregress(slat, shum, (-50, 20), 'Humidity' )
plt.show()
# Out:
# The r-squared is: 0.0009275851449774609

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
ncloud = north_weather_data['Cloudiness']
date = dt.datetime.today().strftime("%m/%d/%Y")


plt.scatter(nlat, ncloud, marker="o", facecolors="blue", edgecolors="black", alpha=0.75)
plt.xlabel('Latitude')
plt.title(f'Northern Hemisphere Latitue vs. Cloudiness ({date})')
plotregress(nlat, ncloud, (45, 40), 'Cloudiness')
plt.show()
# Out:
# The r-squared is: 0.014718137822539046

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
scloud = south_weather_data['Cloudiness']
date = dt.datetime.today().strftime("%m/%d/%Y")


plt.scatter(slat, scloud, marker="o", facecolors="blue", edgecolors="black", alpha=0.75)
plt.xlabel('Latitude')
plt.title(f'Southern Hemisphere Latitue vs. Cloudiness ({date})')
plotregress(slat, scloud, (-55, 10), 'Cloudiness')
plt.show()
# Out:
# The r-squared is: 0.0035627330573137555

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
nlat = north_weather_data['Latitude']
nwind = north_weather_data['Wind Speed']
date = dt.datetime.today().strftime("%m/%d/%Y")


plt.scatter(nlat, nwind, marker="o", facecolors="blue", edgecolors="black", alpha=0.75)
plt.xlabel('Latitude')
plt.title(f'Northern Hemisphere Latitue vs. Wind Speed ({date})')
plotregress(nlat, nwind, (5, 45), 'Wind Speed (miles/hour)')
plt.show()
# Out:
# The r-squared is: 0.015775175602776456

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
swind = south_weather_data['Wind Speed']
date = dt.datetime.today().strftime("%m/%d/%Y")


plt.scatter(slat, swind, marker="o", facecolors="blue", edgecolors="black", alpha=0.75)
plt.xlabel('Latitude')
plt.title(f'Southern Hemisphere Latitue vs. Wind Speed ({date})')
plotregress(slat, swind, (-25, 45), 'Wind Speed (miles/hour)')
plt.show()
# Out:
# The r-squared is: 0.020750289812246265
